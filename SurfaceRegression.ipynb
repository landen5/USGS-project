# %%
import pandas as pd
import plotly.graph_objects as go

data = pd.read_csv('https://raw.githubusercontent.com/landen5/USGS-project/main/coastal_data_raw.csv', header=None)

#3D visual
fig = go.Figure(data=[go.Surface(z=data.values)])

fig.update_layout(title='Transect distance', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))
fig.show()

#coefficients to tune
a = 1.0
b = 1.0
c = 1.0
d = 1.0

#creating new matrix of data calculated by function z = asin(x*(b/pi))ccos(y*(d/pi))
data_new = pd.DataFrame(data)

rows, cols = data_new.shape
for row in range(0, rows):
    for col in range(0, cols):
        print(data_new.at[row, col])
# Out:
# <div>                            <div id="b8abe27a-fc8d-427d-9d37-e6f1bf2a855b" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8abe27a-fc8d-427d-9d37-e6f1bf2a855b")) {                    Plotly.newPlot(                        "b8abe27a-fc8d-427d-9d37-e6f1bf2a855b",                        [{"z":[[2.194963174,0.355948668,-3.082317863,0.723450634,5.371304535,5.035077439,5.126648092,11.31733878,11.29329977,5.277948915,17.68761624,21.37330834,20.44272396,28.45408107,12.3794183,15.19914588,10.2885098,5.800633135],[8.237563964,6.724370964,5.46170177,3.429529126,5.14357929,4.06692931,0.125175292,5.785943234,-4.135291577,-2.269422535,1.556083644,2.153427692,-1.705908543,-6.887701681,-0.912890253,8.961346285,-0.010617753,-2.525792215],[-2.061170983,-4.0664
# ...
